# %%
from google.colab import drive

drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
# %cd /content/gdrive/MyDrive/Colab Notebooks/PCA-CLS
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/PCA-CLS

# %%
# !pwd
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/PCA-CLS

# %%
# !pip install -r requirements.txt

# %%
# !python Bio-NER/main.py --config Bio-NER/demo.train.te.config
# Out:
# Seed num: 42
# MODEL: train
# Training model...
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# DATA SUMMARY START:
#  I/O:
#      Start   Sequence   Laebling   task...
#      Tag          scheme: BIO
#      Split         token:  |||
#      MAX SENTENCE LENGTH: 52
#      MAX   WORD   LENGTH: -1
#      Number   normalized: True
#      Word  alphabet size: 16496
#      Char  alphabet size: 78
#      Label alphabet size: 4
#      Word embedding  dir: None
#      Char embedding  dir: None
#      Word embedding size: 300
#      Char embedding size: 30
#      Norm   word     emb: False
#      Norm   char     emb: False
#      Train  file directory: dataset/BC5CDR-disease/train-dev.tsv
#      Dev    file directory: dataset/BC5CDR-disease/test.tsv
#      Test   file directory: dataset/BC5CDR-disease/test.tsv
#      Raw    file directory: None
#      Dset   file directory: None
# ...

# %%
# !python Bio-NER/main.py --config Bio-NER/demo.train.te.config1
# Out:
# Seed num: 42
# MODEL: train
# Training model...
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# DATA SUMMARY START:
#  I/O:
#      Start   Sequence   Laebling   task...
#      Tag          scheme: BIO
#      Split         token:  |||
#      MAX SENTENCE LENGTH: 52
#      MAX   WORD   LENGTH: -1
#      Number   normalized: True
#      Word  alphabet size: 20190
#      Char  alphabet size: 83
#      Label alphabet size: 4
#      Word embedding  dir: None
#      Char embedding  dir: None
#      Word embedding size: 300
#      Char embedding size: 30
#      Norm   word     emb: False
#      Norm   char     emb: False
#      Train  file directory: dataset/s800/train-dev.tsv
#      Dev    file directory: dataset/s800/test.tsv
#      Test   file directory: dataset/s800/test.tsv
#      Raw    file directory: None
#      Dset   file directory: None
#      Model  file directory: model/s800/cnn_lstm
#      Loadmodel   directory: None
# ...

# %%
# !python Bio-NER/main.py --config Bio-NER/demo.train.te.config2
# Out:
# Seed num: 42
# MODEL: train
# Training model...
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# DATA SUMMARY START:
#  I/O:
#      Start   Sequence   Laebling   task...
#      Tag          scheme: BIO
#      Split         token:  |||
#      MAX SENTENCE LENGTH: 52
#      MAX   WORD   LENGTH: -1
#      Number   normalized: True
#      Word  alphabet size: 9819
#      Char  alphabet size: 78
#      Label alphabet size: 4
#      Word embedding  dir: None
#      Char embedding  dir: None
#      Word embedding size: 300
#      Char embedding size: 30
#      Norm   word     emb: False
#      Norm   char     emb: False
#      Train  file directory: dataset/NCBI-disease/train-dev.tsv
#      Dev    file directory: dataset/NCBI-disease/test.tsv
#      Test   file directory: dataset/NCBI-disease/test.tsv
#      Raw    file directory: None
#      Dset   file directory: None
#      Model  file directory: model/NCBI-disease/cnn_lstm
# ...

# %%
# !python Bio-NER/main.py --config Bio-NER/demo.train.te.config3
# Out:
# Seed num: 42
# MODEL: train
# Training model...
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# DATA SUMMARY START:
#  I/O:
#      Start   Sequence   Laebling   task...
#      Tag          scheme: BIO
#      Split         token:  |||
#      MAX SENTENCE LENGTH: 52
#      MAX   WORD   LENGTH: -1
#      Number   normalized: True
#      Word  alphabet size: 24448
#      Char  alphabet size: 87
#      Label alphabet size: 4
#      Word embedding  dir: None
#      Char embedding  dir: None
#      Word embedding size: 300
#      Char embedding size: 30
#      Norm   word     emb: False
#      Norm   char     emb: False
#      Train  file directory: dataset/Linneaus/train-dev.tsv
#      Dev    file directory: dataset/Linneaus/test.tsv
#      Test   file directory: dataset/Linneaus/test.tsv
#      Raw    file directory: None
#      Dset   file directory: None
#      Model  file directory: model/Linneaus/cnn_lstm
# ...

# %%
# !python Bio-NER/main.py --config Bio-NER/demo.train.te.config4
# Out:
# Seed num: 42
# MODEL: train
# Training model...
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# DATA SUMMARY START:
#  I/O:
#      Start   Sequence   Laebling   task...
#      Tag          scheme: BIO
#      Split         token:  |||
#      MAX SENTENCE LENGTH: 52
#      MAX   WORD   LENGTH: -1
#      Number   normalized: True
#      Word  alphabet size: 22389
#      Char  alphabet size: 76
#      Label alphabet size: 12
#      Word embedding  dir: None
#      Char embedding  dir: None
#      Word embedding size: 300
#      Char embedding size: 30
#      Norm   word     emb: False
#      Norm   char     emb: False
#      Train  file directory: dataset/JNLPBA/train-dev.tsv
#      Dev    file directory: dataset/JNLPBA/test.tsv
#      Test   file directory: dataset/JNLPBA/test.tsv
#      Raw    file directory: None
#      Dset   file directory: None
#      Model  file directory: model/JNLPBA/cnn_lstm
# ...

# %%
# !python Bio-NER/main.py --config Bio-NER/demo.train.te.config5
# Out:
# Seed num: 42
# MODEL: train
# Training model...
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# DATA SUMMARY START:
#  I/O:
#      Start   Sequence   Laebling   task...
#      Tag          scheme: BIO
#      Split         token:  |||
#      MAX SENTENCE LENGTH: 52
#      MAX   WORD   LENGTH: -1
#      Number   normalized: True
#      Word  alphabet size: 35929
#      Char  alphabet size: 79
#      Label alphabet size: 4
#      Word embedding  dir: None
#      Char embedding  dir: None
#      Word embedding size: 300
#      Char embedding size: 30
#      Norm   word     emb: False
#      Norm   char     emb: False
#      Train  file directory: dataset/BC2GM/train-dev.tsv
#      Dev    file directory: dataset/BC2GM/test.tsv
#      Test   file directory: dataset/BC2GM/test.tsv
#      Raw    file directory: None
#      Dset   file directory: None
#      Model  file directory: model/BC2GM/cnn_lstm
#      Loadmodel   directory: None
# ...

# %%
# !python Bio-NER/main.py --config Bio-NER/demo.train.te.config6
# Out:
# Seed num: 42
# MODEL: train
# Training model...
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# DATA SUMMARY START:
#  I/O:
#      Start   Sequence   Laebling   task...
#      Tag          scheme: BIO
#      Split         token:  |||
#      MAX SENTENCE LENGTH: 52
#      MAX   WORD   LENGTH: -1
#      Number   normalized: True
#      Word  alphabet size: 16496
#      Char  alphabet size: 78
#      Label alphabet size: 4
#      Word embedding  dir: None
#      Char embedding  dir: None
#      Word embedding size: 300
#      Char embedding size: 30
#      Norm   word     emb: False
#      Norm   char     emb: False
#      Train  file directory: dataset/BC5CDR-chem/train-dev.tsv
#      Dev    file directory: dataset/BC5CDR-chem/test.tsv
#      Test   file directory: dataset/BC5CDR-chem/test.tsv
#      Raw    file directory: None
#      Dset   file directory: None
#      Model  file directory: model/BC5CDR-chem/cnn_lstm
# ...

# %%
# !python Bio-NER/main.py --config Bio-NER/demo.train.te.config7
# Out:
# Seed num: 42
# MODEL: train
# Training model...
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# DATA SUMMARY START:
#  I/O:
#      Start   Sequence   Laebling   task...
#      Tag          scheme: BIO
#      Split         token:  |||
#      MAX SENTENCE LENGTH: 52
#      MAX   WORD   LENGTH: -1
#      Number   normalized: True
#      Word  alphabet size: 66794
#      Char  alphabet size: 87
#      Label alphabet size: 4
#      Word embedding  dir: None
#      Char embedding  dir: None
#      Word embedding size: 300
#      Char embedding size: 30
#      Norm   word     emb: False
#      Norm   char     emb: False
#      Train  file directory: dataset/BC4CHEMD/train-dev.tsv
#      Dev    file directory: dataset/BC4CHEMD/test.tsv
#      Test   file directory: dataset/BC4CHEMD/test.tsv
#      Raw    file directory: None
#      Dset   file directory: None
#      Model  file directory: model/BC4CHEMD/cnn_lstm
# ...
